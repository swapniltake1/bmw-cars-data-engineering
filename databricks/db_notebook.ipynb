# %%
# %sql
CREATE CATALOG IF NOT EXISTS BMW_Cars_Catalog COMMENT 'Catalog for BMW cars data';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS BMW_Cars_Catalog.Silver COMMENT 'Schema for BMW cars data';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS BMW_Cars_Catalog.gold COMMENT 'Schema for BMW cars data';
